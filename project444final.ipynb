# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/road_accident(USETHIS).csv")
df.head()
# Out:
#                State  Road Accidents  during 2018  \
# 0     Andhra Pradesh                        24475
# 1  Arunachal Pradesh                          277
# 2              Assam                         8248
# 3              Bihar                         9600
# 4       Chhattisgarh                        13864
#
#     Road Accidents  during 2019  Road Accidents  during 2020  \
# 0                         21992                      19509.0
# 1                           237                        134.0
# 2                          8350                       6595.0
# 3                         10007                       8639.0
# 4                         13899                      11656.0
#
#    Accidents  Per Lakh Population - 2017  \
# 0                                   28.7
# 1                                   18.0
# 2                                   21.6
# 3                                    8.3
# 4                                   51.2
#
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.shape
# Out:
# (36, 45)

# %%
df.columns
# Out:
# Index(['State', 'Road Accidents  during 2018', 'Road Accidents  during 2019',
#        'Road Accidents  during 2020', 'Accidents  Per Lakh Population - 2017',
#        'Total Number of Accidents  Per Lakh Population - 2018',
#        'Total Number of Accidents  Per Lakh Population - 2019',
#        'Total Number of Accidents  Per Lakh Population - 2020',
#        'Accidents per 10,000 Vehicles - 2017',
#        'Accidents per 10,000 Vehicles - 2018',
#        'Accidents per 10,000 Vehicles - 2019',
#        'Accidents per 10,000 Km of Roads - 2017',
#        'Accidents per 10,000 Km of Roads - 2018', 'Persons Killed 2017',
#        'Persons Killed 2018', 'Persons Killed 2019', 'Persons Killed 2020',
#        'Share in Death- 2017', 'Share in Death- 2018', 'Share in Death- 2019',
#        'Share in Death- 2020', 'Persons Killed Per Lakh Population - 2017',
#        'Persons Killed Per Lakh Population - 2018',
#        'Persons Killed Per Lakh Population - 2019',
# ...

# %%
df.columns=[i.replace(' ','_')for i in df.columns]

df.columns
# Out:
# Index(['State', 'Road_Accidents__during_2018', 'Road_Accidents__during_2019',
#        'Road_Accidents__during_2020', 'Accidents__Per_Lakh_Population_-_2017',
#        'Total_Number_of_Accidents__Per_Lakh_Population_-_2018',
#        'Total_Number_of_Accidents__Per_Lakh_Population_-_2019',
#        'Total_Number_of_Accidents__Per_Lakh_Population_-_2020',
#        'Accidents_per_10,000_Vehicles_-_2017',
#        'Accidents_per_10,000_Vehicles_-_2018',
#        'Accidents_per_10,000_Vehicles_-_2019',
#        'Accidents_per_10,000_Km_of_Roads_-_2017',
#        'Accidents_per_10,000_Km_of_Roads_-_2018', 'Persons_Killed_2017',
#        'Persons_Killed_2018', 'Persons_Killed_2019', 'Persons_Killed_2020',
#        'Share_in_Death-_2017', 'Share_in_Death-_2018', 'Share_in_Death-_2019',
#        'Share_in_Death-_2020', 'Persons_Killed_Per_Lakh_Population_-_2017',
#        'Persons_Killed_Per_Lakh_Population_-_2018',
#        'Persons_Killed_Per_Lakh_Population_-_2019',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 45 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   State                                                  36 non-null     object
#  1   Road_Accidents__during_2018                            36 non-null     int64
#  2   Road_Accidents__during_2019                            36 non-null     int64
#  3   Road_Accidents__during_2020                            35 non-null     float64
#  4   Accidents__Per_Lakh_Population_-_2017                  35 non-null     float64
#  5   Total_Number_of_Accidents__Per_Lakh_Population_-_2018  35 non-null     float64
#  6   Total_Number_of_Accidents__Per_Lakh_Population_-_2019  35 non-null     float64
#  7   Total_Number_of_Accidents__Per_Lakh_Population_-_2020  35 non-null     float64
# ...

# %%
print(df.isnull().sum())  # Displays count of missing values per column
# Out:
# State                                                    0
# Road_Accidents__during_2018                              0
# Road_Accidents__during_2019                              0
# Road_Accidents__during_2020                              1
# Accidents__Per_Lakh_Population_-_2017                    1
# Total_Number_of_Accidents__Per_Lakh_Population_-_2018    1
# Total_Number_of_Accidents__Per_Lakh_Population_-_2019    1
# Total_Number_of_Accidents__Per_Lakh_Population_-_2020    1
# Accidents_per_10,000_Vehicles_-_2017                     0
# Accidents_per_10,000_Vehicles_-_2018                     1
# Accidents_per_10,000_Vehicles_-_2019                     1
# Accidents_per_10,000_Km_of_Roads_-_2017                  0
# Accidents_per_10,000_Km_of_Roads_-_2018                  0
# Persons_Killed_2017                                      0
# Persons_Killed_2018                                      0
# Persons_Killed_2019                                      0
# ...

# %%
df.fillna(0, inplace=True)  # Replace NaN (empty cells) with 0

# %%
print(df.isnull().sum())  # Displays count of missing values per column
# Out:
# State                                                    0
# Road_Accidents__during_2018                              0
# Road_Accidents__during_2019                              0
# Road_Accidents__during_2020                              0
# Accidents__Per_Lakh_Population_-_2017                    0
# Total_Number_of_Accidents__Per_Lakh_Population_-_2018    0
# Total_Number_of_Accidents__Per_Lakh_Population_-_2019    0
# Total_Number_of_Accidents__Per_Lakh_Population_-_2020    0
# Accidents_per_10,000_Vehicles_-_2017                     0
# Accidents_per_10,000_Vehicles_-_2018                     0
# Accidents_per_10,000_Vehicles_-_2019                     0
# Accidents_per_10,000_Km_of_Roads_-_2017                  0
# Accidents_per_10,000_Km_of_Roads_-_2018                  0
# Persons_Killed_2017                                      0
# Persons_Killed_2018                                      0
# Persons_Killed_2019                                      0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Make sure pandas is imported

# Sort the DataFrame by 'Road_Accidents__during_2018' in descending order
df_sorted = df.sort_values(by=['Road_Accidents__during_2018'], ascending=False)[1:21]

plt.figure(figsize=(12, 6))
# Use the correct column name, replacing spaces with underscores
# Use the sorted DataFrame for plotting
plt.bar(df_sorted["State"], df_sorted["Road_Accidents__during_2018"], color='blue')
plt.xlabel("States")
plt.ylabel("Number of Accidents")
plt.title("Road Accidents in 2018 (Sorted)")  # Update the title
plt.xticks(rotation=90)  # Rotate state names for readability
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Make sure pandas is imported

# Sort the DataFrame by 'Road_Accidents__during_2018' in descending order
df_sorted = df.sort_values(by=['Road_Accidents__during_2019'], ascending=False)[1:21]

plt.figure(figsize=(12, 6))
# Use the correct column name, replacing spaces with underscores
# Use the sorted DataFrame for plotting
plt.bar(df_sorted["State"], df_sorted["Road_Accidents__during_2019"], color='green')
plt.xlabel("States")
plt.ylabel("Number of Accidents")
plt.title("Road Accidents in 2019 (Sorted)")  # Update the title
plt.xticks(rotation=90)  # Rotate state names for readability
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Make sure pandas is imported

# Sort the DataFrame by 'Road_Accidents__during_2018' in descending order
df_sorted = df.sort_values(by=['Road_Accidents__during_2020'], ascending=False)[1:21]

plt.figure(figsize=(12, 6))
# Use the correct column name, replacing spaces with underscores
# Use the sorted DataFrame for plotting
plt.bar(df_sorted["State"], df_sorted["Road_Accidents__during_2020"], color='red')
plt.xlabel("States")
plt.ylabel("Number of Accidents")
plt.title("Road Accidents in 2020 (Sorted)")  # Update the title
plt.xticks(rotation=90)  # Rotate state names for readability
plt.show()

# %%
low_2018=df.sort_values(by='Road_Accidents__during_2018')[:5]
low_2018
# Out:
#                      State  Road_Accidents__during_2018  \
# 34             Lakshadweep                            3
# 17                 Mizoram                           53
# 32           Daman and Diu                           76
# 31  Dadra and Nagar Haveli                           80
# 22                  Sikkim                          180
#
#     Road_Accidents__during_2019  Road_Accidents__during_2020  \
# 34                            1                          1.0
# 17                           62                         53.0
# 32                           69                          0.0
# 31                           68                        100.0
# 22                          162                        138.0
#
#     Accidents__Per_Lakh_Population_-_2017  \
# 34                                    1.2
# 17                                    6.3
# 32                                   22.0
# 31                                   14.8
# ...

# %%
low_2019=df.sort_values(by='Road_Accidents__during_2019')[:5]
low_2019
# Out:
#                      State  Road_Accidents__during_2018  \
# 34             Lakshadweep                            3
# 17                 Mizoram                           53
# 31  Dadra and Nagar Haveli                           80
# 32           Daman and Diu                           76
# 22                  Sikkim                          180
#
#     Road_Accidents__during_2019  Road_Accidents__during_2020  \
# 34                            1                          1.0
# 17                           62                         53.0
# 31                           68                        100.0
# 32                           69                          0.0
# 22                          162                        138.0
#
#     Accidents__Per_Lakh_Population_-_2017  \
# 34                                    1.2
# 17                                    6.3
# 31                                   14.8
# 32                                   22.0
# ...

# %%
low_2020=df.sort_values(by='Road_Accidents__during_2020')[:5]
low_2020
# Out:
#                      State  Road_Accidents__during_2018  \
# 32           Daman and Diu                           76
# 34             Lakshadweep                            3
# 17                 Mizoram                           53
# 31  Dadra and Nagar Haveli                           80
# 1        Arunachal Pradesh                          277
#
#     Road_Accidents__during_2019  Road_Accidents__during_2020  \
# 32                           69                          0.0
# 34                            1                          1.0
# 17                           62                         53.0
# 31                           68                        100.0
# 1                           237                        134.0
#
#     Accidents__Per_Lakh_Population_-_2017  \
# 32                                   22.0
# 34                                    1.2
# 17                                    6.3
# 31                                   14.8
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(3, 1, figsize=(15, 18))  # 3 rows, 1 column

# Assuming you have DataFrames named low_acc_2018, low_acc_2019, low_acc_2020
# containing the lowest accident data for each year

# Subplot for 2018
sns.barplot(data=low_2018, x='State', y='Road_Accidents__during_2018', ax=axes[0])
axes[0].set_title("Lowest Accident in 2018 State Wise", fontsize=14, pad=14)
axes[0].set_xlabel('State', fontsize=12)
axes[0].set_ylabel('Accidents During 2018', fontsize=12)

# Subplot for 2019
sns.barplot(data=low_2019, x='State', y='Road_Accidents__during_2019', ax=axes[1])  # Assuming column name for 2019
axes[1].set_title("Lowest Accident in 2019 State Wise", fontsize=14, pad=14)
axes[1].set_xlabel('State', fontsize=12)
axes[1].set_ylabel('Accidents During 2019', fontsize=12)

# Subplot for 2020
sns.barplot(data=low_2020, x='State', y='Road_Accidents__during_2020', ax=axes[2])  # Assuming column name for 2020
axes[2].set_title("Lowest Accident in 2020 State Wise", fontsize=14, pad=14)
axes[2].set_xlabel('State', fontsize=12)
axes[2].set_ylabel('Accidents During 2020', fontsize=12)

# Rotate x-axis labels for all subplots
for ax in axes:
    ax.tick_params(axis='x', which='major', labelsize=12, rotation=90)
    ax.tick_params(axis='y', which='major', labelsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df' and has columns:
# 'Total Number of Accidents Per Lakh Population - 2018'
# 'Total Number of Accidents Per Lakh Population - 2019'
# 'Total Number of Accidents Per Lakh Population - 2020'
plt.tight_layout()
# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(12, 12), sharex=True)  # 3 rows, 1 column

# Plot data for each year in separate subplots
axes[0].plot(df["Total_Number_of_Accidents__Per_Lakh_Population_-_2018"], marker='o', color='blue', linestyle='-', label="2018")
axes[0].set_ylabel("Accidents per Lakh")
axes[0].set_title("Total Accidents per Lakh Population - 2018")
axes[0].set_xlabel("State")

axes[1].plot(df["State"], df["Total_Number_of_Accidents__Per_Lakh_Population_-_2019"], marker='s', color='green', linestyle='-', label="2019")
axes[1].set_ylabel("Accidents per Lakh")
axes[1].set_title("Total Accidents per Lakh Population - 2019")
axes[1].set_xlabel("State")

axes[2].plot(df["State"], df["Total_Number_of_Accidents__Per_Lakh_Population_-_2020"], marker='d', color='red', linestyle='-', label="2020")
axes[2].set_ylabel("Accidents per Lakh")
axes[2].set_title("Total Accidents per Lakh Population - 2020")
axes[2].set_xlabel("State")


# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sort data for each year in ascending order
df_sorted_2018 = df.sort_values(by=['Share_in_Death-_2018'], ascending=False)[1:21]
df_sorted_2019 = df.sort_values(by=['Share_in_Death-_2019'], ascending=False)[1:21]
df_sorted_2020 = df.sort_values(by=['Share_in_Death-_2020'], ascending=False)[1:21]

bar_width = 0.25  # Width of each bar
# Use the length of the sorted DataFrame to create the index
index = np.arange(len(df_sorted_2018["State"]))  # Positions of bars

plt.figure(figsize=(12, 6))

# Create bars for each year with different colors and positions using sorted data
plt.bar(index - bar_width, df_sorted_2018["Share_in_Death-_2018"], bar_width, color='blue', label="2018")
plt.bar(index, df_sorted_2019["Share_in_Death-_2019"], bar_width, color='green', label="2019")
plt.bar(index + bar_width, df_sorted_2020["Share_in_Death-_2020"], bar_width, color='red', label="2020")

plt.xlabel("States")
plt.ylabel("Share in Deaths")
plt.title("Death Share Comparison (2018-2020) ")
# Use the sorted state names for the x-axis ticks
plt.xticks(index, df_sorted_2018["State"], rotation=90)  # Center x-axis ticks under groups, using sorted state names
plt.legend()
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named 'df'

# Calculate total accidents for each year
total_accidents_2018 = df['Road_Accidents__during_2018'].sum()
total_accidents_2019 = df['Road_Accidents__during_2019'].sum()
total_accidents_2020 = df['Road_Accidents__during_2020'].sum()

# Data for the pie chart
years = ['2018', '2019', '2020']
accidents = [total_accidents_2018, total_accidents_2019, total_accidents_2020]

# Create the pie chart
plt.figure(figsize=(6, 6))  # Adjust figure size as needed
plt.pie(accidents, labels=years, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Road Accidents - By Year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named 'df'

# Calculate total share of deaths for each year
total_share_2018 = df['Share_in_Death-_2018'].sum()
total_share_2019 = df['Share_in_Death-_2019'].sum()
total_share_2020 = df['Share_in_Death-_2020'].sum()

# Data for the pie chart
years = ['2018', '2019', '2020']
shares = [total_share_2018, total_share_2019, total_share_2020]

# Create the pie chart
plt.figure(figsize=(6, 6))  # Adjust figure size as needed
plt.pie(shares, labels=years, autopct='%1.1f%%', startangle=90)
plt.title('Share of Deaths in Road Accidents - By Year')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named 'df'

# Calculate total deaths for each state across all years
df['Total_Deaths'] = df['Share_in_Death-_2018'] + df['Share_in_Death-_2019'] + df['Share_in_Death-_2020']

# Sort the DataFrame by total deaths in descending order
df_sorted = df.sort_values(by=['Total_Deaths'], ascending=False)

# Get the top 10 states with the highest total deaths
top_10_states = df_sorted.head(10)

# Data for the pie chart
states = top_10_states['State']
deaths = top_10_states['Total_Deaths']

# Create the pie chart
plt.figure(figsize=(8, 8))  # Adjust figure size as needed
plt.pie(deaths, labels=states, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Deaths in Road Accidents Across States (2018-2020)')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd



plt.hist(df["Injury_Per_Lakh_Population_-_2017"], bins=5)  # Adjust bins as needed
plt.xlabel("Injury Per Lakh Population")
plt.ylabel("Frequency")
plt.title(f"Histogram of Injury Per Lakh Population - 2017")
plt.show()

plt.hist(df["Injury_Per_Lakh_Population_-_2017"], bins=5)  # Adjust bins as needed
plt.xlabel("Injury Per Lakh Population")
plt.ylabel("Frequency")
plt.title(f"Histogram of Injury Per Lakh Population - 2018")
plt.show()

plt.hist(df["Injury_Per_Lakh_Population_-_2017"], bins=5)  # Adjust bins as needed
plt.xlabel("Injury Per Lakh Population")
plt.ylabel("Frequency")
plt.title(f"Histogram of Injury Per Lakh Population - 20119")
plt.show()

plt.hist(df["Injury_Per_Lakh_Population_-_2017"], bins=5)  # Adjust bins as needed
plt.xlabel("Injury Per Lakh Population")
plt.ylabel("Frequency")
plt.title(f"Histogram of Injury Per Lakh Population - 2020")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Select the columns for the box plot
accident_columns = ['Road_Accidents__during_2018', 'Road_Accidents__during_2019', 'Road_Accidents__during_2020']

# Create the box plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
sns.boxplot(data=df[accident_columns])
plt.title("Distribution of Road Accidents (2018-2020)")
plt.xlabel("Year")
plt.ylabel("Number of Accidents")
plt.xticks([0, 1, 2], ['2018', '2019', '2020'])  # Set x-axis labels
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Select the columns for the box plot
accidents_per_lakh_columns = [
    'Total_Number_of_Accidents__Per_Lakh_Population_-_2018',
    'Total_Number_of_Accidents__Per_Lakh_Population_-_2019',
    'Total_Number_of_Accidents__Per_Lakh_Population_-_2020'
]

# Create the box plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
sns.boxplot(data=df[accidents_per_lakh_columns])
plt.title("Distribution of Accidents Per Lakh Population (2018-2020)")
plt.xlabel("Year")
plt.ylabel("Accidents Per Lakh Population")
plt.xticks([0, 1, 2], ['2018', '2019', '2020'])  # Set x-axis labels
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df'

# Select the columns for the heatmap
heatmap_columns = [
    'Road_Accidents__during_2018', 'Road_Accidents__during_2019', 'Road_Accidents__during_2020',
    'Persons_Killed_2018', 'Persons_Killed_2019', 'Persons_Killed_2020',

]

# Create a correlation matrix
correlation_matrix = df[heatmap_columns].corr()

# Print the correlation analysis
print("Correlation Analysis:\n", correlation_matrix)

# Create the heatmap
plt.figure(figsize=(8, 8))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)  # Added linewidths
plt.title('Correlation Heatmap of Road Accident Data')
plt.show()

# Create pairplot (optional)
sns.pairplot(df[heatmap_columns])  # Use heatmap_columns for pairplot
plt.show()
# Out:
# Correlation Analysis:
#                               Road_Accidents__during_2018  \
# Road_Accidents__during_2018                     1.000000
# Road_Accidents__during_2019                     0.997470
# Road_Accidents__during_2020                     0.992974
# Persons_Killed_2018                             0.842426
# Persons_Killed_2019                             0.826262
# Persons_Killed_2020                             0.814137
#
#                              Road_Accidents__during_2019  \
# Road_Accidents__during_2018                     0.997470
# Road_Accidents__during_2019                     1.000000
# Road_Accidents__during_2020                     0.994930
# Persons_Killed_2018                             0.847411
# Persons_Killed_2019                             0.835135
# Persons_Killed_2020                             0.824241
#
#                              Road_Accidents__during_2020  Persons_Killed_2018  \
# ...
